# %%
import pandas as pd
import json
df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\NaiveRewards\\naiveReward10k.csv")

print("10K")

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if int(df.iloc[index, 2]) >= 277683:
        spend["high"] += 1
    elif int(df.iloc[index, 2]) >= 138843:
        spend["mid"] +=1 
    else:
        spend["low"] += 1

print("total =>", spend)

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 277683:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 138843:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("naive =>",spend)

df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\ChainRewards\\chainReward10k.csv")
spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 277683:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 138843:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("chain =>",spend)
# Out:
# 10K
# total => {'high': 409, 'mid': 4120, 'low': 5471}
# naive => {'high': 409, 'mid': 1733, 'low': 0}
# chain => {'high': 409, 'mid': 2754, 'low': 1152}

# %%
import pandas as pd
import json
df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\NaiveRewards\\naiveReward50k.csv")

print("50K")

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if int(df.iloc[index, 2]) >= 298545:
        spend["high"] += 1
    elif int(df.iloc[index, 2]) >= 149273:
        spend["mid"] +=1 
    else:
        spend["low"] += 1

print("total =>", spend)

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 298545:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 149273:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("naive =>",spend)

df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\ChainRewards\\chainReward50k.csv")
spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 298545:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 149273:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("chain =>",spend)
# Out:
# 50K
# total => {'high': 1709, 'mid': 20268, 'low': 28023}
# naive => {'high': 1709, 'mid': 10801, 'low': 0}
# chain => {'high': 1709, 'mid': 14887, 'low': 5843}

# %%
import pandas as pd
import json
df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\NaiveRewards\\naiveReward100k.csv")

print("100K")

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if int(df.iloc[index, 2]) >= 302172:
        spend["high"] += 1
    elif int(df.iloc[index, 2]) >= 151086:
        spend["mid"] +=1 
    else:
        spend["low"] += 1

print("total =>", spend)

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 302172:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 151086:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("naive =>",spend)

df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\ChainRewards\\chainReward100k.csv")
spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 302172:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 151086:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("chain =>",spend)
# Out:
# 100K
# total => {'high': 3184, 'mid': 40292, 'low': 56524}
# naive => {'high': 3184, 'mid': 22080, 'low': 0}
# chain => {'high': 3184, 'mid': 29908, 'low': 12039}

# %%
import pandas as pd
import json
df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\NaiveRewards\\naiveReward500k.csv")

print("500K")

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if int(df.iloc[index, 2]) >= 339815:
        spend["high"] += 1
    elif int(df.iloc[index, 2]) >= 169908:
        spend["mid"] +=1 
    else:
        spend["low"] += 1

print("total =>", spend)

spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 339815:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 169908:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("naive =>",spend)

df = pd.read_csv("C:\\Users\\acer\\Dropbox\\Research_Lab\\Free_delivery_system\\Rewards\\ChainRewards\\chainReward500k.csv")
spend = {"high":0, "mid": 0, "low": 0}
for index in range(df.shape[0]):
    if str(df.iloc[index, 4]) == "yes":
        if int(df.iloc[index, 2]) >= 339815:
            spend["high"] += 1
        elif int(df.iloc[index, 2]) >= 169908:
            spend["mid"] +=1 
        else:
            spend["low"] += 1

print("chain =>",spend)
